# %%
import numpy as np

# %%
arr1=np.array([1,2,3,4,5,6])
arr2=np.array([4,5,6,7,8,9])

# %%
arr1-arr2
# Out:
# array([-3, -3, -3, -3, -3, -3])

# %% [markdown]
# vector multiplication

# %%
arr1*arr2
# Out:
# array([ 4, 10, 18, 28, 40, 54])

# %% [markdown]
# scalar multiplication

# %%
arr1*2
# Out:
# array([ 2,  4,  6,  8, 10, 12])

# %%
arr1>3
# Out:
# array([False, False, False,  True,  True,  True])

# %%
arr3=np.arange(6).reshape(2,3)
arr4=np.arange(6,12).reshape(3,2)

# %%
arr3.dot(arr4)
# Out:
# array([[ 28,  31],
#        [100, 112]])

# %%
arr1.dot(arr2)
# Out:
# 154

# %% [markdown]
# Matrix multiplication works only if:
#
#
# (m×n)⋅(n×p)
#
# Columns of first matrix = Rows of second matrix
#
# If they don’t match →  error

# %%
arr1.dot(arr3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 arr1.dot(arr3)
#
# ValueError: shapes (6,) and (2,3) not aligned: 6 (dim 0) != 2 (dim 0)

# %%
arr4
# Out:
# array([[ 6,  7],
#        [ 8,  9],
#        [10, 11]])

# %%
arr4.max()
# Out:
# 11

# %%
arr4.min()
# Out:
# 6

# %%
arr4.max(axis=0)
# Out:
# array([10, 11])

# %%
arr4.max(axis=1)
# Out:
# array([ 7,  9, 11])

# %%
arr4.min(axis=0)
# Out:
# array([6, 7])

# %%
arr4.min(axis=1)
# Out:
# array([ 6,  8, 10])

# %%
arr4.sum()
# Out:
# 51

# %%
arr4.sum(axis=0)
# Out:
# array([24, 27])

# %%
arr4.sum(axis=1)
# Out:
# array([13, 17, 21])

# %%
arr4.mean()
# Out:
# 8.5

# %% [markdown]
# This difference comes from:
#
# 🔹 Object-Oriented Programming (OOP)
#
# You are studying OOP right now 👀
#
# arr4.min() → Method call (object-oriented style)
#
# np.median(arr4) → Functional style

# %%
np.median(arr4)
# Out:
# 8.5

# %%
arr4.std()
# Out:
# 1.707825127659933

# %%
np.sin(arr4)
# Out:
# array([[-0.2794155 ,  0.6569866 ],
#        [ 0.98935825,  0.41211849],
#        [-0.54402111, -0.99999021]])

# %%
np.exp(arr4)
# Out:
# array([[  403.42879349,  1096.63315843],
#        [ 2980.95798704,  8103.08392758],
#        [22026.46579481, 59874.1417152 ]])
