# %%
import numpy as np

# %%
arr4=np.arange(6,12).reshape(3,2)
arr4
# Out:
# array([[ 6,  7],
#        [ 8,  9],
#        [10, 11]])

# %% [markdown]
# array dimentions

# %%
arr4.ndim
# Out:
# 2

# %% [markdown]
# **revel()**: we can change dimention of array from high dimention into 1 dimention.

# %%
arr4.ravel()
# Out:
# array([ 6,  7,  8,  9, 10, 11])

# %% [markdown]
# **transpoose**: convert rows into colums

# %%
arr4.transpose()
# Out:
# array([[ 6,  8, 10],
#        [ 7,  9, 11]])

# %% [markdown]
# **stacking**:  make one array from two arrays .(comn=bine arrays) in vertical and horizental both

# %%
arr5=np.arange(12,18).reshape(2,3)
arr5
# Out:
# array([[12, 13, 14],
#        [15, 16, 17]])

# %%
arr3=np.arange(6).reshape(2,3)
arr3
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %% [markdown]
# horizental

# %%
np.hstack((arr3,arr5))
# Out:
# array([[ 0,  1,  2, 12, 13, 14],
#        [ 3,  4,  5, 15, 16, 17]])

# %% [markdown]
# vertical

# %%
np.vstack((arr3,arr5))
# Out:
# array([[ 0,  1,  2],
#        [ 3,  4,  5],
#        [12, 13, 14],
#        [15, 16, 17]])

# %% [markdown]
# **spliting**: split array into two ways, horizental and verticals

# %%
arr3
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %% [markdown]
# vetical split

# %%
np.vsplit(arr3,2)
# Out:
# [array([[0, 1, 2]]), array([[3, 4, 5]])]

# %% [markdown]
# horizental

# %%
np.hsplit(arr3,3)
# Out:
# [array([[0],
#         [3]]),
#  array([[1],
#         [4]]),
#  array([[2],
#         [5]])]
