# %%
import numpy as np

# %%
np.random.random()
# Out:
# 0.06494381329015919

# %%
np.random.seed(5)
np.random.random()
# Out:
# 0.22199317108973948

# %%
np.random.uniform(1,100)
# Out:
# 76.82487779155124

# %%
np.random.uniform(1,100,10).reshape(2,5)
# Out:
# array([[30.31191334, 63.25000298, 58.40394321, 60.39299047, 27.31609264],
#        [29.18390218, 26.10523237, 33.42883082, 15.27226576, 17.39567326]])

# %%
np.random.randint(1,10,5)
# Out:
# array([2, 6, 8, 1, 7], dtype=int32)

# %%
a = np.random.randint(1,10,6)
a
# Out:
# array([1, 6, 3, 1, 8, 8], dtype=int32)

# %%
np.max(a)
# Out:
# np.int32(8)

# %%
np.min(a)
# Out:
# np.int32(1)

# %%
np.argmax(a) # index of max value
# Out:
# np.int64(4)

# %%
np.argmin(a) # index of min value
# Out:
# np.int64(0)

# %%
a = np.random.randint(1,10,6)
a
# Out:
# array([7, 5, 6, 3, 9, 9], dtype=int32)

# %%
a[a%2==1]=-1 # change all even numbers to -1
a
# Out:
# array([-1, -1,  6, -1, -1, -1], dtype=int32)

# %%
a = np.random.randint(1,50,6)
a
# Out:
# array([34, 29, 16,  7, 36, 48], dtype=int32)

# %%
np.where(a%2==1, -1, a) # change all odd numbers to -1, keep even numbers as they are
# Out:
# array([34, -1, 16, -1, 36, 48], dtype=int32)

# %%
a
# Out:
# array([34, 29, 16,  7, 36, 48], dtype=int32)

# %%
out = np.where(a%2==1, -1, a)
out
# Out:
# array([34, -1, 16, -1, 36, 48], dtype=int32)

# %%
a = np.random.randint(1,50,10)
a
# Out:
# array([21,  9, 33, 19, 14, 29, 48, 19, 18, 23], dtype=int32)

# %%
a = np.sort(a)
a
# Out:
# array([ 9, 14, 18, 19, 19, 21, 23, 29, 33, 48], dtype=int32)

# %%
np.percentile(a, 25) # 25th percentile
# Out:
# np.float64(18.25)

# %%
np.percentile(a, 50) # 50th percentile (median)
# Out:
# np.float64(20.0)

# %%
np.percentile(a, 99.8) # 99.8th percentile
# Out:
# np.float64(47.72999999999999)
